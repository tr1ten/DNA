# %% [markdown]
# f(x) = min(a+x,b-x)

# %%
def f(x): return min(a+x,b-x)

# %%
# graph when 
# a == b
import matplotlib.pyplot as plt
a = 50
b = 50
x = range(0, 30)
y = [f(i) for i in x] 
plt.plot(x, y)

# %%
# a < b
a = 25
b = 50
x = range(0, 30)
y = [f(i) for i in x]
plt.plot(x, y)

# %%
# a > b
a = 50
b = 25
x = range(0, 25)
y = [f(i) for i in x]
plt.plot(x, y)
